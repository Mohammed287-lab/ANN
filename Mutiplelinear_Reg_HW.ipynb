# %% [markdown]
# <a href="https://colab.research.google.com/github/Mohammed287-lab/ANN/blob/main/Mutiplelinear_Reg_HW.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math
import seaborn as sns

elements = { 'x':[1,2,3,4,5,6],'y':[6,7,3,5,4,2]}
df = pd.DataFrame(elements)

# %%
sns.lineplot(x='x', y='y', data=df)

plt.title("Line Plot using Seaborn")
plt.xlabel("X Values")
plt.ylabel("Y Values")
plt.show( )

# %%
import matplotlib.pyplot as plt

x = df['x']
y = df['y']
plt.plot(x,y)
plt.title("Line Plot using Matplotlib")
plt.xlabel("X Values")
plt.ylabel("Y Values")
plt.show()

# %%
from sklearn.datasets import load_iris
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load dataset
iris = load_iris()

# Convert to DataFrame
df = pd.DataFrame(data=iris.data, columns=iris.feature_names)
df['species'] = iris.target

# Replace numeric target with species names
df['species'] = df['species'].map({0:'setosa',1:'versicolor',2:'virginica'})

# Seaborn pairplot
sns.pairplot(df, hue='species')

plt.show()

# %%
from sklearn.datasets import load_iris
iris = load_iris()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn.datasets as sk

#
iris = sk.load_iris()

df = pd.DataFrame(iris.data, columns=iris.feature_names)


df['species'] = iris.target
df['species'] = df['species'].map({0:'setosa',1:'versicolor',2:'virginica'})


__builtins__.print(df.head())
__builtins__.print(df.shape)
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#   species
# 0  setosa
# 1  setosa
# 2  setosa
# 3  setosa
# 4  setosa
# (150, 5)
