# %% [markdown]
# <a href="https://colab.research.google.com/github/Mohammed287-lab/ANN/blob/main/new%20linear%20regggission%20corect%20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math


elements = { 'x':[1,2,3,4,5,6],'y':[6,4,3,5,4,2]}
df = pd.DataFrame(elements)

# %%
x_mean = df['x'].mean()
y_mean = df['y'].mean()

df['x^2']= df['x']**2
df['y^2']= df['y']**2
df['xy']= df['x']*df['y']

# %%
x_total = df['x'].sum()
y_total = df['y'].sum()
x_square_total = df['x^2'].sum()
y_square_total = df['y^2'].sum()
xy_total = df['xy'].sum()

# %%
import math
n= len(df)
Slop= (((n*xy_total)-  (x_total*y_total))  /((n*x_square_total)-(x_total**2)))
Coefficient =((( y_total*x_square_total)-(x_total*xy_total))/((n*x_square_total)-(x_total**2)))

df['y_predict'] = Coefficient + Slop * df['x']
df['Error'] = df['y'] - df['y_predict']

df ["squared error"] = df["Error"]**2
SSE = df["squared error"].sum()

df ["absolute error"] = df["Error"].abs()
SAE =df["absolute error"].sum()

RMSE = math.sqrt ((SSE/len(df["squared error"])))

# %%
plt.scatter(df['x'],df['y'])
plt.plot(df['x'],df['y_predict'])

plt.show()

# %%
x_input = input("Enter X :")
y_prediction = Coefficient + (Slop * float(x_input))
print('Predicted Y value:', y_prediction)
print('Sum of Squared Errors (SSE):', SSE)
print('Sum of Absolute Errors (SAE):', SAE)
print('Root Mean Squared Error (RMSE):', RMSE)
# Out:
# Enter X :3
# Predicted Y value: 4.257142857142857
# Sum of Squared Errors (SSE): 5.371428571428572
# Sum of Absolute Errors (SAE): 5.485714285714286
# Root Mean Squared Error (RMSE): 0.9461702252967461
