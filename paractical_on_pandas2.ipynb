# %% [markdown]
# <a href="https://colab.research.google.com/github/Mohammed287-lab/ANN/blob/main/paractical_on_pandas2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

data = {
    'Name': ["Alice", "Bob", "Claire"],
    'Age': [25, 30, 27],
    'city': ['New York', 'San Francisco', 'Los Angeles'],
    'sarlary': [100, 150, 200]
}

df = pd.DataFrame(data)
df
# Out:
#      Name  Age           city  sarlary
# 0   Alice   25       New York      100
# 1     Bob   30  San Francisco      150
# 2  Claire   27    Los Angeles      200

# %%
df[['Name','Age']]
# Out:
#      Name  Age
# 0   Alice   25
# 1     Bob   30
# 2  Claire   27

# %%
df.iloc[1]
# Out:
# Name                 Bob
# Age                   30
# city       San Francisco
# sarlary              150
# Name: 1, dtype: object

# %%
df['Age'].mean()
# Out:
# 27.333333333333332

# %%
print("The minimum salary is",df['sarlary'].min())
print("The maximum salary is",df['sarlary'].max())
print("The mean salary is",df['sarlary'].mean())
# Out:
# The minimum salary is 100
# The maximum salary is 200
# The mean salary is 150.0

# %%
ndata= [10,20,30,40]
s=pd.Series(ndata)

print(s.min())
print(s.max())
print(s.mean())
# Out:
# 10
# 40
# 25.0

# %%
df
# Out:
#      Name  Age           city  sarlary
# 0   Alice   25       New York      100
# 1     Bob   30  San Francisco      150
# 2  Claire   27    Los Angeles      200

# %%
df.head(2)
# Out:
#     Name  Age           city  sarlary
# 0  Alice   25       New York      100
# 1    Bob   30  San Francisco      150

# %%
df.tail(1)
# Out:
#      Name  Age         city  sarlary
# 2  Claire   27  Los Angeles      200

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Name     3 non-null      object
#  1   Age      3 non-null      int64
#  2   city     3 non-null      object
#  3   sarlary  3 non-null      int64
# dtypes: int64(2), object(2)
# memory usage: 224.0+ bytes

# %%
df.describe().T
# Out:
#          count        mean        std    min    25%    50%    75%    max
# Age        3.0   27.333333   2.516611   25.0   26.0   27.0   28.5   30.0
# sarlary    3.0  150.000000  50.000000  100.0  125.0  150.0  175.0  200.0

# %%
df
# Out:
#      Name  Age           city  sarlary
# 0   Alice   25       New York      100
# 1     Bob   30  San Francisco      150
# 2  Claire   27    Los Angeles      200

# %%
merged_df = pd.merge(df, df, on='Name')
merged_df
# Out:
#      Name  Age_x         city_x  sarlary_x  Age_y         city_y  sarlary_y
# 0   Alice     25       New York        100     25       New York        100
# 1     Bob     30  San Francisco        150     30  San Francisco        150
# 2  Claire     27    Los Angeles        200     27    Los Angeles        200

# %%
df['New sarlary'] = df['sarlary'].apply(lambda x: x+30)
df
# Out:
#      Name  Age           city  sarlary  New sarlary
# 0   Alice   25       New York      100          130
# 1     Bob   30  San Francisco      150          180
# 2  Claire   27    Los Angeles      200          230

# %%
sorted_df = df.sort_values(by='Age')
sorted_df
# Out:
#      Name  Age           city  sarlary  New sarlary
# 0   Alice   25       New York      100          130
# 2  Claire   27    Los Angeles      200          230
# 1     Bob   30  San Francisco      150          180

# %%
df['is_adult'] = df['Age'].apply(lambda x: True if x >= 26 else False)
df
# Out:
#      Name  Age           city  sarlary  New sarlary  is_adult
# 0   Alice   25       New York      100          130     False
# 1     Bob   30  San Francisco      150          180      True
# 2  Claire   27    Los Angeles      200          230      True

# %%
df=pd.read_csv('/diabetes.csv')
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df['Pregnancies'].unique()
# Out:
# array([ 6,  1,  8,  0,  5,  3, 10,  2,  4,  7,  9, 11, 13, 15, 17, 12, 14])

# %%
df['Outcome'].unique()
# Out:
# array([1, 0])

# %%
correlation_matrix = df.corr()
correlation_matrix
# Out:
#                           Pregnancies   Glucose  BloodPressure  SkinThickness  \
# Pregnancies                  1.000000  0.129459       0.141282      -0.081672
# Glucose                      0.129459  1.000000       0.152590       0.057328
# BloodPressure                0.141282  0.152590       1.000000       0.207371
# SkinThickness               -0.081672  0.057328       0.207371       1.000000
# Insulin                     -0.073535  0.331357       0.088933       0.436783
# BMI                          0.017683  0.221071       0.281805       0.392573
# DiabetesPedigreeFunction    -0.033523  0.137337       0.041265       0.183928
# Age                          0.544341  0.263514       0.239528      -0.113970
# Outcome                      0.221898  0.466581       0.065068       0.074752
#
#                            Insulin       BMI  DiabetesPedigreeFunction  \
# Pregnancies              -0.073535  0.017683                 -0.033523
# ...

# %%
df=df.rename(columns={'DiabetesPedigreeFunction':'DPF'})
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI    DPF  \
# 0            6      148             72             35        0  33.6  0.627
# 1            1       85             66             29        0  26.6  0.351
# 2            8      183             64              0        0  23.3  0.672
# 3            1       89             66             23       94  28.1  0.167
# 4            0      137             40             35      168  43.1  2.288
#
#    Age  Outcome
# 0   50        1
# 1   31        0
# 2   32        1
# 3   21        0
# 4   33        1
