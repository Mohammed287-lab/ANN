# %% [markdown]
# <a href="https://colab.research.google.com/github/Mohammed287-lab/ANN/blob/main/practical_on_pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd


data = {
    "Name": ["Alice", "Bob", "Charlie"],
    "Age": [25, 30, 35],
    "City": ["New York", "San Francisco", "Los Angeles"],
    'salary':[100,150,200,]

}
df = pd.DataFrame(data)
print(df)
# Out:
#       Name  Age           City  salary
# 0    Alice   25       New York     100
# 1      Bob   30  San Francisco     150
# 2  Charlie   35    Los Angeles     200

# %%
import pandas as pd


data = {
    "Name": ["Alice", "Bob", "Charlie"],
    "Age": [25, 30, 35],
    "City": ["New York", "San Francisco", "Los Angeles"],
    'salary':[100,150,200] #Modified: Changed the length of salary list to 3 to match other columns.
}


df = pd.DataFrame(data)
print(df)

# %%
df[['Name','Age']]
# Out:
#       Name  Age
# 0    Alice   25
# 1      Bob   30
# 2  Charlie   35

# %%
df['salary']
# Out:
# 0    100
# 1    150
# 2    200
# Name: salary, dtype: int64

# %%
df['Age'].mean()
# Out:
# 30.0

# %%
print("The miniuum age is ",df['Age'].min())
print("The maximum age is ",df['Age'].max())
print("The average age is ",df['Age'].mean())
# Out:
# The miniuum age is  25
# The maximum age is  35
# The average age is  30.0

# %%
ndata = [10,20,,30,40,50]
s=pd

# %%
df.head(2)
# Out:
#     Name  Age           City  salary
# 0  Alice   25       New York     100
# 1    Bob   30  San Francisco     150

# %%
df.tail(2)
# Out:
#       Name  Age           City  salary
# 1      Bob   30  San Francisco     150
# 2  Charlie   35    Los Angeles     200

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    3 non-null      object
#  1   Age     3 non-null      int64
#  2   City    3 non-null      object
#  3   salary  3 non-null      int64
# dtypes: int64(2), object(2)
# memory usage: 224.0+ bytes

# %%
df.describe().T
# Out:
#         count   mean   std    min    25%    50%    75%    max
# Age       3.0   30.0   5.0   25.0   27.5   30.0   32.5   35.0
# salary    3.0  150.0  50.0  100.0  125.0  150.0  175.0  200.0

# %%
merged_df=pd.merge(df,df,on='Name')
merged_df
# Out:
#       Name  Age_x         City_x  salary_x  Age_y         City_y  salary_y
# 0    Alice     25       New York       100     25       New York       100
# 1      Bob     30  San Francisco       150     30  San Francisco       150
# 2  Charlie     35    Los Angeles       200     35    Los Angeles       200

# %%
df['New_sarlary']=df['salary'].apply(lambda x:x+30)
df
# Out:
#       Name  Age           City  salary  New_sarlary
# 0    Alice   25       New York     100          130
# 1      Bob   30  San Francisco     150          180
# 2  Charlie   35    Los Angeles     200          230

# %%
sorted_df=df.sort_values(by='salary')
sorted_df
# Out:
#       Name  Age           City  salary  is_adult
# 0    Alice   25       New York     100     False
# 1      Bob   30  San Francisco     150      True
# 2  Charlie   35    Los Angeles     200      True

# %%
df['is_adult'] = df['Age'].apply(lambda x: True if x >= 27 else False)
df
# Out:
#       Name  Age           City  salary  is_adult
# 0    Alice   25       New York     100     False
# 1      Bob   30  San Francisco     150      True
# 2  Charlie   35    Los Angeles     200      True

# %%
df1 =  pd.read_csv('diabetes.csv')
df1.head
# Out:
# <bound method NDFrame.head of      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# ...
